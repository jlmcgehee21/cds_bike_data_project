# %%
# %matplotlib inline


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


import mpld3
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## Read in csv file
#
# Remember to replace with your own file path

# %%
bike_df = pd.read_csv("/Users/jeff/bike_data/data/df.csv", parse_dates=[6, 7, 8, 9, 11, 13, 14])

#print dataframe columns
print(bike_df.columns)

#print the 10th row of the dataframe
print("Here is the 10th row!")
bike_df.ix[9]
# Out:
# Index([u'EndStationName', u'StartStationName', u'SubscriberID', u'MemberType',
#        u'TripDurationSec', u'BikeID', u'StartDay', u'StartDateTime',
#        u'StartDate', u'StartTime', u'StartStationID', u'EndDay',
#        u'EndDateTime', u'EndDate', u'EndTime', u'EndStationID',
#        u'tripDurationHours', u'yearStart', u'monthStart', u'latlonStart',
#        u'latlonEnd'],
#       dtype='object')
# Here is the 10th row!
# EndStationName        100 Manufacturers Rd
# StartStationName        High St & E 2nd St
# SubscriberID                         33691
# MemberType                        Customer
# TripDurationSec                       2330
# BikeID                              C00132
# StartDay                          Saturday
# StartDateTime          2014-02-22 13:34:00
# StartDate              2014-02-22 00:00:00
# StartTime              2016-01-12 13:34:00
# StartStationID                        1321
# EndDay                            Saturday
# EndDateTime            2014-02-22 14:13:00
# EndDate                2014-02-22 00:00:00
# EndTime                2016-01-12 14:13:00
# EndStationID                          1297
# tripDurationHours                     0.65
# yearStart                             2014
# monthStart                               2
# latlonStart          35.054855, -85.305476
# latlonEnd            35.061546, -85.310370
# Name: 9, dtype: object

# %% [markdown]
# ## Station and Trip Popularity
#
# Let's look at which stations get used the most.  The first chart shows the starting station sorted by number of trips, and the second has the ending station sorted by number of trips

# %%
# Group stations
grouped_df = bike_df['StartStationName'].value_counts()

# Make bar chart
grouped_df.plot(kind='bar')

# %%
# Group stations
grouped_df = bike_df['EndStationName'].value_counts()

# Make bar chart
grouped_df.plot(kind='bar')

# %%
trips = bike_df['StartStationName'] + '--' + bike_df['EndStationName']

trips.value_counts()[:10].sort_values().plot(kind='barh')

# %%
trips.loc[bike_df['StartStationName'] != bike_df['EndStationName']].value_counts()[:10].sort_values().plot(kind='barh')

# %% [markdown]
# ## Popular Time to Ride

# %%
bike_df["StartDay"].value_counts().plot(kind='bar')

# %%
time_windows={22: 'late_night',
              23: 'late_night',
              0: 'late_night',
              1: 'late_night',
              2: 'late_night',
              3: 'late_night',
              4: 'late_night',
              5: 'early_morning',
              6: 'early_morning',
              7: 'early_morning',
              8: 'morning',
              9: 'morning',
              10: 'morning',
              11: 'mid_day',
              12: 'mid_day',
              13: 'mid_day',
              14: 'afternoon',
              15: 'afternoon',
              16: 'afternoon',
              17: 'afternoon',
              18: 'evening',
              19: 'evening',
              20: 'evening',
              21: 'evening',
             }

bike_df['StartTime'].apply(lambda x: time_windows[x.hour]).value_counts().plot(kind='bar')

# %% [markdown]
# ## Individual Bike Information

# %%
print '%d total bikes' % bike_df['BikeID'].unique().shape[0]
# Out:
# 297 total bikes

# %%
grouped_by_bikes = bike_df.groupby("BikeID")

bike_total_hours = grouped_by_bikes["tripDurationHours"].sum()

bike_total_hours.sort_values(ascending=False)[:10].plot(kind='bar')

# %%
cleaned = bike_total_hours[np.abs(bike_total_hours - bike_total_hours.mean()) < 3*bike_total_hours.std()]

cleaned.plot(kind='hist')

# %%
#Most frequently visited station per bike

station_counts = grouped_by_bikes['StartStationName'].value_counts()

station_data = {}
for bike_id in station_counts.index.levels[0]:
    station_data[bike_id] = station_counts[bike_id].argmax()
    
station_data = pd.Series(station_data)
# print(station_data)

favorite_stations = station_data.value_counts()

favorite_stations.plot(kind='barh')

# %%
short_trips = bike_df[bike_df['TripDurationSec']<60]

new_bike_df = bike_df.copy()

new_bike_df['NeedsRepair'] = short_trips['StartStationName'] == short_trips['EndStationName']


new_bike_df = new_bike_df.set_index(new_bike_df['StartDateTime'])

by_serial = new_bike_df.groupby('BikeID')

repair_counts = new_bike_df['BikeID'][new_bike_df['NeedsRepair'].fillna(False)].value_counts()

# repair_counts[:10].plot(kind='bar')
# repair_counts.plot(kind='hist')

# %%
df = pd.concat((bike_total_hours, repair_counts, station_data), axis=1).fillna(0)
df.columns =  ['TotalHours', 'NeedsRepair', 'FavoriteStation']

df.plot(kind='scatter', x='TotalHours', y='NeedsRepair')
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el327748277265449205983027"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el327748277265449205983027", {"axes": [{"xlim": [-50.0, 400.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "TotalHours", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.068426197458455532], "rotation": -0.0, "id": "el32774827762320"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "NeedsRepair", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.065188172043010736, 0.5], "rotation": -90.0, "id": "el32774828069968"}], "zoomable": true, "images": [], "xdomain": [-50.0, 400.0], "ylim": [-20.0, 100.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 10, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "10,0", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [], "markers": [], "id": "el32774826231632", "ydomain": [-20.0, 100.0], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#000000"], "edgewidths": [0.3], "offsets": "data01", "yindex": 1, "id": "el32774829568656", "pathtransforms": [[4.969039949999533, 0.0, 0.0, 4.969039949999533, 0.0, 0.0]], "pathcoordinates": "display", "offsetcoordinates": "data", "zorder": 1, "xindex": 0, "alphas": [null], "facecolors": ["#4C72B0"]}], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}], "data": {"data01": [[283.96000000000004, 19.0], [186.98000000000005, 10.0], [283.7400000000002, 19.0], [259.14999999999986, 24.0], [274.35999999999996, 20.0], [205.19000000000017, 17.0], [198.61999999999992, 20.0], [198.6499999999999, 19.0], [283.3599999999996, 31.0], [252.07000000000005, 12.0], [262.91, 24.0], [161.55999999999997, 22.0], [280.8600000000003, 18.0], [286.46000000000015, 28.0], [314.44, 20.0], [290.61999999999966, 22.0], [230.54000000000036, 23.0], [216.35000000000016, 21.0], [258.9100000000001, 25.0], [245.78000000000014, 23.0], [310.4, 13.0], [287.20000000000016, 24.0], [340.4399999999999, 29.0], [292.93000000000023, 17.0], [216.6599999999998, 17.0], [256.33999999999986, 23.0], [265.78000000000026, 21.0], [246.0699999999998, 20.0], [305.82, 24.0], [276.53, 13.0], [314.6799999999998, 16.0], [236.43000000000004, 19.0], [289.5200000000004, 24.0], [237.83000000000013, 12.0], [241.46, 25.0], [279.1900000000002, 74.0], [275.8399999999999, 11.0], [235.3, 11.0], [310.96999999999986, 19.0], [199.59000000000015, 21.0], [241.7299999999998, 16.0], [262.81000000000023, 17.0], [272.3599999999998, 19.0], [244.30999999999995, 15.0], [256.57000000000016, 12.0], [297.8, 15.0], [212.95999999999987, 14.0], [204.52999999999994, 24.0], [228.79000000000005, 14.0], [135.9000000000001, 17.0], [292.4899999999997, ...

# %%
df.corr()
# Out:
#              TotalHours  NeedsRepair
# TotalHours     1.000000     0.179696
# NeedsRepair    0.179696     1.000000

# %%
df.sort_values(by='NeedsRepair', ascending=False)[:50]['FavoriteStation'].value_counts().plot(kind='bar')

# %%
new_bike_df = bike_df.copy()
new_bike_df = new_bike_df.set_index(new_bike_df['StartDateTime'])

bike_hours_by_id = new_bike_df.loc[new_bike_df['BikeID'].isin(df.sort_values(by='TotalHours', ascending=False)[:11].index)][['BikeID', 'tripDurationHours', 'StartDateTime']]

# %%
# test_df = bike_hours_by_id.apply(lambda x: x['tripDurationHours'].cumsum()).reset_index()

per_bike = pd.pivot_table(bike_hours_by_id, index='StartDateTime', columns='BikeID', values='tripDurationHours').sort_index()

for bike in per_bike.columns:
    per_bike[bike] = per_bike[bike].cumsum()
    

per_bike = per_bike.fillna(method='bfill')

# %%
ax = per_bike.plot(figsize=(10,8))
ax.set_xlabel('Date')
ax.yaxis.labelpad = 10
ax.set_ylabel('Total Hours Ridden')
ax.set_title('Cumulative Usage of 10 Most Used Bikes')
ax.grid(axis='y')

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el327748850523044990338190"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el327748850523044990338190", {"axes": [{"xlim": [734707.25972222222, 735749.88749999995], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "hanging", "h_anchor": "middle", "color": "#262626", "text": "Date", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [0.5, -0.10405934681066453], "rotation": -0.0, "id": "el32774786554192"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Total Hours Ridden", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 11.0, "position": [-0.060707885304659495, 0.5], "rotation": -90.0, "id": "el32774959708560"}, {"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "Cumulative Usage of 10 Most Used Bikes", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0124007936507937], "rotation": -0.0, "id": "el32774959873808"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "BikeID", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.046359767025089593, 0.9598214285714286], "rotation": -0.0, "id": "el32774962348880"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00025", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.9250992063492065], "rotation": -0.0, "id": "el32774962052112"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00082", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.89037698412698418], "rotation": -0.0, "id": "el32774962103952"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00144", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.85565476190476208], "rotation": -0.0, "id": "el32774962106576"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00149", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.82093253968253976], "rotation": -0.0, "id": "el32774962150224"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00218", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.78621031746031744], "rotation": -0.0, "id": "el32774962151312"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00227", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.75148809523809534], "rotation": -0.0, "id": "el32774962199056"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00228", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.71676587301587302], "rotation": -0.0, "id": "el32774962246800"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00267", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.6820436507936507], "rotation": -0.0, "id": "el32774962249424"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00278", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.6473214285714286], "rotation": -0.0, "id": "el32774962250128"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00287", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.61259920634920628], "rotation": -0.0, "id": "el32774962289552"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#262626", "text": "C00294", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 10.0, "position": [0.066308243727598581, 0.57787698412698418], "rotation": -0.0, "id": "el32774 ...
